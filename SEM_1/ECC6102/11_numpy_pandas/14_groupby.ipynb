# %%
import pandas as pd
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('drinks.csv')
#drinks.head()

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
# calculate the mean beer servings across the entire dataset
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
# calculate the mean beer servings just for countries in Africa
drinks[drinks.continent == 'Africa']
drinks[drinks.continent == 'Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
# calculate the mean beer servings for each continent

# get the seriess of all the continents and then compute average
drinks.groupby('continent').beer_servings

drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
# other aggregation functions (such as 'max') can also be used with groupby
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
# multiple aggregation functions can be applied simultaneously
drinks.groupby('continent').beer_servings.agg(['count', 'mean', 'min', 'max'])
# Out:
#                count        mean  min  max
# continent
# Africa            53   61.471698    0  376
# Asia              44   37.045455    0  247
# Europe            45  193.777778    0  361
# North America     23  145.434783    1  285
# Oceania           16   89.687500    0  306
# South America     12  175.083333   93  333

# %%
# Get the mean of all the columns - continent wise
# specifying a column to which the aggregation function should be applied is not required
drinks.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# allow plots to appear in the notebook
# %matplotlib inline

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='bar')

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='line')

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='hist')

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='kde')

# %%
# side-by-side bar plot of the DataFrame directly above - horizontal bars
drinks.groupby('continent').mean().plot(kind='barh')

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='box')

# %%
# side-by-side bar plot of the DataFrame directly above
drinks.groupby('continent').mean().plot(kind='pie', subplots=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b51cd7d9aa2a> in <module>()
#       1 # side-by-side bar plot of the DataFrame directly above
# ----> 2 drinks.groupby('continent').mean().plot(kind='pie')
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# ...
