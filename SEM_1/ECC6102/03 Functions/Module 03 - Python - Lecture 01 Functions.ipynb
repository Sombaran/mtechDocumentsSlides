# %% [markdown]
# Global Variable Examples

# %%
# float greet_rahul()
# {
#     printf("Hello Rahul");
#     return 3.140;
# }

# %%
#1. **Simple Function Definition**

def greet_rahul():
    print("Namaste, Rahul!")
    print("Last line of the function")

greet_rahul()  #calling the function

print("Hello!")
# Out:
# Namaste, Rahul!
# Last line of the function
# Hello!

# %%
x = int(input("Enter the value of x: "))
y = int(input("Enter the value of y: "))
sum = x + y
print("The sum of x and y = ", sum)
# Out:
# Enter the value of x: 15
# Enter the value of y: 8
# The sum of x and y =  23

# %%
def rainbow():
  x = int(input("Enter the value of x: "))
  y = int(input("Enter the value of y: "))
  sum = x + y
  print("The addition6 of x and y = ", sum) #last line

print("This is the main function")
rainbow()
print("Goodbye!")
rainbow()
print("End of Program")
# Out:
# This is the main function
# Enter the value of x: 15
# Enter the value of y: 54
# The addition of x and y =  69
# Goodbye!
# Enter the value of x: 12
# Enter the value of y: 5
# The addition of x and y =  17
# End of Program

# %%
#2. **Function with Parameters**
def rainbow():
  x = int(input("Enter the value of x: "))
  y = int(input("Enter the value of y: "))
  sum = x + y
  print("The addition6 of x and y = ", sum) #last line

def welcome_message(name):
   print(f"Welcome to the course, {name}!")

welcome_message("Preeti")
welcome_message("Aditya")
# welcome_message()
# Out:
# Welcome to the course, Preeti!
# Welcome to the course, Aditya!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-266675666.py in <cell line: 0>()
#      11 welcome_message("Preeti")
#      12 welcome_message("Aditya")
# ---> 13 welcome_message()
#
# TypeError: welcome_message() missing 1 required positional argument: 'name'

# %%
#3. **Function with Return Value**

def sum_numbers(a, b, c):
   return a + b + c  #55

result = sum_numbers(12, 20, 23)
print(result)
print(sum_numbers(1,6,9))
# Out:
# 55
# 16

# %%
#4. **Function with Default Parameter**

def introduce(name="Anil"):
   print(f"My name is {name}.")

introduce("Deepa")
introduce()

introduce("Aditya")
# Out:
# My name is Deepa.
# My name is Anil.
# My name is Aditya.

# %%
#5. **Function with Default Parameter**

def introduce(rainbow):
   print(type(rainbow))
   for name in rainbow:
     print(f"Hello, {name}. Welcome to Python")

names = ["Aditya", "Preeti", "Suresh"]
introduce(names)
# Out:
# <class 'list'>
# Hello, Aditya. Welcome to Python
# Hello, Preeti. Welcome to Python
# Hello, Suresh. Welcome to Python

# %%
#4. **Function with List Passing**

def introduce(names):
   print(type(names))
   names[1] = "Sachin"
   for name in names:
     print(f"Hello, {name} . Welcome to Python")

names = ["Aditya", "Preeti", "Suresh"]
introduce(names)
print(names)

# %%
#5. **Function with Keyword Arguments**
# age=30, name="Sita", roll="99"
def display_info(name, roll, age):
   print(f"{name} is {age} years old and her roll number is {roll}")

display_info("Sita", 26, 99)
display_info("26", "Sita", "99")
display_info(age=30, name="Sita", roll="99")
# Out:
# Sita is 99 years old and her roll number is 26
# 26 is 99 years old and her roll number is Sita
# Sita is 30 years old and her roll number is 99

# %%
#6. **Variable Length Arguments (`*args`)**

def list_friends(*friends):
   print("My friends are:", friends)
   print(type(friends))
   print(len(friends))
   for i in friends:
    print(f"Hi, {i}")

list_friends("Arjun", "Vijay")
list_friends("Arjun", "Vijay", "Kavita", "Sachin", "Rahul", "Sourav")
# Out:
# My friends are: ('Arjun', 'Vijay')
# <class 'tuple'>
# 2
# Hi, Arjun
# Hi, Vijay
# My friends are: ('Arjun', 'Vijay', 'Kavita', 'Sachin', 'Rahul', 'Sourav')
# <class 'tuple'>
# 6
# Hi, Arjun
# Hi, Vijay
# Hi, Kavita
# Hi, Sachin
# Hi, Rahul
# Hi, Sourav

# %%
#7. **Function with Multiple Return Values**

def student_marks(maths, science):
   total = maths + science
   average = total / 2
   return total, average

total_marks, avg_marks = student_marks(85, 90)
print(f"Total: {total_marks}, Average: {avg_marks}")
# Out:
# Total: 175, Average: 87.5

# %%
#8. **Anonymous (Lambda) Function**

double = lambda x: x ** 2

# def double(x):
#   return x ** 2

print(double(25))  # Output: 30
# Out:
# 625

# %%
#9. **Function with `**kwargs` (Keyword Arguments)**

def display_student_info(**info):
   print(type(info))
   for key, value in info.items():
	   print(f"{key}: {value}")

display_student_info(name="Rohit", age=22, subject="Math", sport="Cricket")

capitals = {
 "India" : "New Delhi",
 "Australia" : "Canberra",
 "France" : "Paris"

}
# Out:
# <class 'dict'>
# name: Rohit
# age: 22
# subject: Math
# sport: Cricket

# %%
#10. **Recursive Function**

def factorial(n):
   if n == 1:
     return 1
   else:
	   return n * factorial(n - 1) # 5 * factorial(4)

result = factorial(5)
print(f"Factorial of 5 is {result}")
# Out:
# Factorial of 5 is 120

# %% [markdown]
# 5 * fact(4)
# 5 * 4 * fact(3)
# 5 * 4 * 3 * fact(2)
# 5 * 4 * 3 * 2 * 1
